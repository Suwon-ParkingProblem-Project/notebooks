# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import make_scorer, mean_squared_error, mean_absolute_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from sklearn.model_selection import GridSearchCV
import optuna
plt.rcParams['font.family'] = 'Malgun Gothic'  # Windows 사용 시
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

# %%
# 1. 데이터 로딩
df = pd.read_csv('데이터프레임_수정_v05.csv', encoding = 'cp949') 

# 단속건수 기준 내림차순 정렬
df_sorted = df.sort_values(by='단속건수', ascending=False)

# %%
df['적정 주차면수'] = df['주차면수 합'] + df['가중치*단속건수']

# 2. 독립변수 / 종속변수 지정
X = df[['생활 인구', '소매업', '의료기관', '교육기관', '카드소비', '서비스업', '음식점', '지역면적(km^2)', '버스정류장수', '추정 차량등록수', '근린생활시설수']]
y = df['적정 주차면수']  # = 주차면수 합 + 단속건수*가중치

# %% [markdown]
# # 모델별 변수 선택 및 성능 비교 전략
# 본 프로젝트에서는 XGBoost, Random Forest, CatBoost 세 가지 모델의 성능을 공정하게 비교하기 위해, 각 모델에 대해 Optuna 기반 하이퍼파라미터 튜닝과 변수 선택(feature selection)을 동시에 수행하였다.
#
# 이를 위해 다음과 같은 전략을 사용하였다:
#
# 각 변수에 대해 사용 여부(use or not)를 이진 변수로 설정하고,
#
# Optuna가 이를 포함한 채 동시에 하이퍼파라미터 최적값을 탐색하도록 구성하였다.
#
# 즉, 모델이 스스로 “어떤 변수를 포함할지”와 “어떻게 튜닝할지”를 함께 학습한다.
#
# 이 과정을 통해 얻은 각 모델의
# - 최적 하이퍼파라미터 조합
# - 선택된 변수 목록
# - 교차검증 기반 성능 지표(R² 등)
#
# 을 비교하여 최종 사용할 모델을 선정한다.

# %%
def objective_xgb(trial):
    # 리스트 내포로 변수 선택
    selected_features = [col for col in X.columns if trial.suggest_categorical(f"use_{col}", [True, False])]

    # 최소 1개 변수 선택 강제
    if len(selected_features) == 0:
        return -float("inf")

    X_selected = X[selected_features]

    # 하이퍼파라미터 튜닝
    params = {
        'n_estimators': 100,
        'max_depth': trial.suggest_int('max_depth', 3, 6),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 5.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 5.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10)
    }

    model = XGBRegressor(**params, random_state=0)
    score = cross_val_score(model, X_selected, y, cv=10, scoring='r2').mean()
    return score

# Optuna 실행
study_xgb = optuna.create_study(direction='maximize')
study_xgb.optimize(objective_xgb, n_trials=50)

# 결과 출력
print("🎯 Best R²:", study_xgb.best_value)
print("✅ Best params:", study_xgb.best_params)

# 선택된 변수 목록 추출
selected_cols = [col for col in X.columns if study_xgb.best_params.get(f"use_{col}", False)]
print("🔍 선택된 변수들:", selected_cols)
# Out:
# [I 2025-05-20 14:31:44,067] A new study created in memory with name: no-name-29965af6-b07e-40c3-a3bb-bee34114783f
# [I 2025-05-20 14:31:44,426] Trial 0 finished with value: 0.23847232203707494 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': False, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'max_depth': 6, 'learning_rate': 0.0570378819241197, 'subsample': 0.90496500967159, 'colsample_bytree': 0.6936090445217861, 'reg_alpha': 0.4526461051639019, 'reg_lambda': 1.3449286615176914, 'min_child_weight': 9}. Best is trial 0 with value: 0.23847232203707494.
# [I 2025-05-20 14:31:44,947] Trial 1 finished with value: 0.36701292678324476 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': False, 'use_서비스업': True, 'use_음식점': False, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'max_depth': 6, 'learning_rate': 0.04595693369344248, 'subsample': 0.9391519838061885, 'colsample_bytree': 0.9925088891878114, 'reg_alpha': 0.5990322672287496, 'reg_lambda': 1.7213128672549933, 'min_child_weight': 3}. Best is trial 1 with value: 0.36701292678324476.
# [I 2025-05-20 14:31:45,414] Trial 2 finished with value: -0.15627633514506376 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': False, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': False, 'use_근린생활시설수': True, 'max_depth': 3, 'learning_rate': 0.07856856784525434, 'subsample': 0.9055213675730021, 'colsample_bytree': 0.9546924178971044, 'reg_alpha': 3.6090555898951178, 'reg_lambda': 0.11016968247853143, 'min_child_weight': 10}. Best is trial 1 with value: 0.36701292678324476.
# [I 2025-05-20 14:31:45,812] Trial 3 finished with value: 0.5060583797080141 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'max_depth': 5, 'learning_rate': 0.013885213707198779, 'subsample': 0.7092750342829505, 'colsample_bytree': 0.8001651572090476, 'reg_alpha': 1.2637867482820198, 'reg_lambda': 0.13129500587566123, 'min_child_weight': 7}. Best is trial 3 with value: 0.5060583797080141.
# [I 2025-05-20 14:31:46,129] Trial 4 finished with value: 0.12441049314465605 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': False, 'use_카드소비': False, 'use_서비스업': True, 'use_음식점': False, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'max_depth': 4, 'learning_rate': 0.03676891663511179, 'subsample': 0.8477985719720478, 'colsample_bytree': 0.7855224092859773, 'reg_alpha': 0.4492673047540513, 'reg_lambda': 0.7126649381907002, 'min_child_weight': 9}. Best is trial 3 with value: 0.5060583797080141.
# [I 2025-05-20 14:31:46,582] Trial 5 finished with value: -0.018948131210087028 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': False, 'use_서비스업': True, 'use_음식점': False, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'max_depth': 4, 'learning_rate': 0.09320440042784259, 'subsample': 0.7167076691439873, 'colsample_bytree': 0.9736588068984176, 'reg_alpha': 2.6855718356091565, 'reg_lambda': 4.484803837726318, 'min_child_weight': 1}. Best is trial 3 with value: 0.5060583797080141.
# [I 2025-05-20 14:31:47,114] Trial 6 finished with value: 0.4053437213265824 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': False, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': False, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'max_depth': 3, 'learning_rate': 0.011108037885657996, 'subsample': 0.7384576040146478, 'colsample_bytree': 0.7482399922256399, 'reg_alpha': 0.13350119971404673, 'reg_lambda': 2.6496048893749458, 'min_child_weight': 5}. Best is trial 3 with value: 0.5060583797080141.
# [I 2025-05-20 14:31:47,761] Trial 7 finished with value: 0.2376919137638578 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': False, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'max_depth': 3, 'learning_rate': 0.029037461484945196, 'subsample': 0.6261442229219947, 'colsample_bytree': 0.6015126155520446, 'reg_alpha': 0.1630186697060365, 'reg_lambda': 2.837757315316334, 'min_child_weight': 5}. Best is trial 3 with value: 0.5060583797080141.
# [I 2025-05-20 14:31:48,723] Trial 8 finished with value: -1.2023644648025409 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': True, 'use_카드소비': False, 'use_서비스업': False, 'use_음식점': False, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'max_depth': 4, 'learning_rate': 0.09347287886572919, 'subsample': 0.6140652904950684, 'colsample_bytree': 0.6348938989615779, 'reg_alpha': 1.273184570586603, 'reg_lambda': 4.132216963074528, 'min_child_weight': 5}. Best is trial 3 with value: 0.5060583797080141.
# [I 2025-05-20 14:31:50,214] Trial 9 finished with value: 0.34177865561830056 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': False, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'max_depth': 4, 'learning_rate': 0.06112065050549558, 'subsample': 0.9302867653911562, 'colsample_bytree': 0.9231483231435313, 'reg_alpha': 2.0241644574699476, 'reg_lambda': 3.877306360212965, 'min_child_weight': 7}. Best is trial 3 with value: 0.5060583797080141.
# [I 2025-05-20 14:31:51,059] Trial 10 finished with value: 0.49308822952277415 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': False, 'use_근린생활시설수': True, 'max_depth': 5, 'learning_rate': 0.01058731372125771, 'subsample': 0.7584596416330077, 'colsample_bytree': 0.8536085827698514, 'reg_alpha': 4.8685229332966635, 'reg_lambda': 1.806474035572299, 'min_child_weight': 7}. Best is trial 3 with value: 0.5060583797080141.
# [I 2025-05-20 14:31:51,871] Trial 11 finished with value: 0.48948068333886197 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': False, 'use_근린생활시설수': True, 'max_depth': 5, 'learning_rate': 0.01154945451614539, 'subsample': 0.7576847077692743, 'colsample_bytree': 0.866811910999452, 'reg_alpha': 4.677098181236314, 'reg_lambda': 1.7747500389970017, 'min_child_weight': 7}. Best is trial 3 with value: 0.5060583797080141.
# [I 2025-05-20 14:31:52,695] Trial 12 finished with value: 0.46319615802004854 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': False, 'use_근린생활시설수': True, 'max_depth': 5, 'learning_rate': 0.025249730651737, 'subsample': 0.6729131359361972, 'colsample_bytree': 0.8524145626252412, 'reg_alpha': 4.814191887466623, 'reg_lambda': 0.1005926497935126, 'min_child_weight': 7}. Best is trial 3 with value: 0.5060583797080141.
# [I 2025-05-20 14:31:53,866] Trial 13 finished with value: 0.5033466060568803 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': False, 'use_근린생활시설수': True, 'max_depth': 5, 'learning_rate': 0.018785091598498546, 'subsample': 0.8124069474682181, 'colsample_bytree': 0.847271493393407, 'reg_alpha': 3.1166606655715245, 'reg_lambda': 3.3281687328081717, 'min_child_weight': 8}. Best is trial 3 with value: 0.5060583797080141.
# [I 2025-05-20 14:31:54,938] Trial 14 finished with value: 0.4463247940972713 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'max_depth': 6, 'learning_rate': 0.025450522206608615, 'subsample': 0.8412329484953245, 'colsample_bytree': 0.7755297368733639, 'reg_alpha': 2.982873264889847, 'reg_lambda': 3.4142009206488027, 'min_child_weight': 8}. Best is trial 3 with value: 0.5060583797080141.
# [I 2025-05-20 14:31:56,055] Trial 15 finished with value: 0.26330759539244486 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': False, 'use_근린생활시설수': True, 'max_depth': 5, 'learning_rate': 0.04522331279638286, 'subsample': 0.9946008206385085, 'colsample_bytree': 0.7321120909750835, 'reg_alpha': 1.7408052591361034, 'reg_lambda': 3.098930630625441, 'min_child_weight': 9}. Best is trial 3 with value: 0.5060583797080141.
# [I 2025-05-20 14:31:57,487] Trial 16 finished with value: 0.32227034285694367 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': False, 'use_근린생활시설수': True, 'max_depth': 5, 'learning_rate': 0.06922641351238726, 'subsample': 0.6800840640918435, 'colsample_bytree': 0.9018749364779152, 'reg_alpha': 3.2619342316155766, 'reg_lambda': 4.840055008255224, 'min_child_weight': 3}. Best is trial 3 with value: 0.5060583797080141.
# [I 2025-05-20 14:31:58,553] Trial 17 finished with value: 0.5115538120383787 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'max_depth': 6, 'learning_rate': 0.0193649531780592, 'subsample': 0.8071338973102108, 'colsample_bytree': 0.8247731293838709, 'reg_alpha': 3.863573946501565, 'reg_lambda': 2.2705138012421493, 'min_child_weight': 6}. Best is trial 17 with value: 0.5115538120383787.
# [I 2025-05-20 14:31:59,711] Trial 18 finished with value: 0.4000436380194706 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'max_depth': 6, 'learning_rate': 0.03165348781674092, 'subsample': 0.7873845090348024, 'colsample_bytree': 0.8078545194155593, 'reg_alpha': 4.116678599646016, 'reg_lambda': 0.6904257946488603, 'min_child_weight': 3}. Best is trial 17 with value: 0.5115538120383787.
# [I 2025-05-20 14:32:00,730] Trial 19 finished with value: 0.3678182130431612 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'max_depth': 6, 'learning_rate': 0.04056788278707447, 'subsample': 0.6964929593360056, 'colsample_bytree': 0.6927528260186298, 'reg_alpha': 2.118527515502564, 'reg_lambda': 2.2785031322043916, 'min_child_weight': 6}. Best is trial 17 with value: 0.5115538120383787.
# [I 2025-05-20 14:32:02,227] Trial 20 finished with value: 0.4938939801898846 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'max_depth': 6, 'learning_rate': 0.019345988584467094, 'subsample': 0.8453483772618234, 'colsample_bytree': 0.8152132346720468, 'reg_alpha': 1.1257201933734686, 'reg_lambda': 0.921828466174776, 'min_child_weight': 4}. Best is trial 17 with value: 0.5115538120383787.
# [I 2025-05-20 14:32:03,102] Trial 21 finished with value: 0.516701306103079 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'max_depth': 5, 'learning_rate': 0.019810360618586813, 'subsample': 0.8135436983941209, 'colsample_bytree': 0.8229486451747394, 'reg_alpha': 3.786375004342728, 'reg_lambda': 3.6155690333409414, 'min_child_weight': 6}. Best is trial 21 with value: 0.516701306103079.
# [I 2025-05-20 14:32:03,928] Trial 22 finished with value: 0.5215529512689879 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'max_depth': 5, 'learning_rate': 0.018850597120419033, 'subsample': 0.7966289696298539, 'colsample_bytree': 0.7492190905357425, 'reg_alpha': 3.944416080899403, 'reg_lambda': 3.8089988924587486, 'min_child_weight': 6}. Best is trial 22 with value: 0.5215529512689879.
# [I 2025-05-20 14:32:04,853] Trial 23 finished with value: 0.517343226250067 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'max_depth': 5, 'learning_rate': 0.02060568506690298, 'subsample': 0.7873757833435505, 'colsample_bytree': 0.7317053997879949, 'reg_alpha': 4.015426820059414, 'reg_lambda': 3.7252055334790226, 'min_child_weight': 6}. Best is trial 22 with value: 0.5215529512689879.
# [I 2025-05-20 14:32:06,249] Trial 24 finished with value: 0.4344530629078345 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'max_depth': 5, 'learning_rate': 0.03482690084278283, 'subsample': 0.7814118971851055, 'colsample_bytree': 0.7066497719923567, 'reg_alpha': 4.030498793253428, 'reg_lambda': 3.7996928488271697, 'min_child_weight': 4}. Best is trial 22 with value: 0.5215529512689879.
# [I 2025-05-20 14:32:07,212] Trial 25 finished with value: 0.3986009300221831 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'max_depth': 4, 'learning_rate': 0.049086740074701096, 'subsample': 0.8738547256868128, 'colsample_bytree': 0.6604351400135919, 'reg_alpha': 4.3541542042598405, 'reg_lambda': 4.221983285792769, 'min_child_weight': 6}. Best is trial 22 with value: 0.5215529512689879.
# [I 2025-05-20 14:32:08,229] Trial 26 finished with value: 0.5213103656261824 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'max_depth': 5, 'learning_rate': 0.02414728203371993, 'subsample': 0.8180440066097917, 'colsample_bytree': 0.7540952689909887, 'reg_alpha': 3.5320677771202673, 'reg_lambda': 3.581780463681438, 'min_child_weight': 4}. Best is trial 22 with value: 0.5215529512689879.
# [I 2025-05-20 14:32:09,370] Trial 27 finished with value: 0.45554388804961404 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'max_depth': 4, 'learning_rate': 0.0266394647482378, 'subsample': 0.868605070354262, 'colsample_bytree': 0.7522147815099198, 'reg_alpha': 3.5316175300906916, 'reg_lambda': 4.96055985158865, 'min_child_weight': 2}. Best is trial 22 with value: 0.5215529512689879.
# [I 2025-05-20 14:32:10,568] Trial 28 finished with value: 0.5343939073326731 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'max_depth': 5, 'learning_rate': 0.03901277485783683, 'subsample': 0.7659626310092138, 'colsample_bytree': 0.7327325384866712, 'reg_alpha': 4.443125505386029, 'reg_lambda': 4.499434156764725, 'min_child_weight': 4}. Best is trial 28 with value: 0.5343939073326731.
# [I 2025-05-20 14:32:11,448] Trial 29 finished with value: 0.28014967526216716 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': False, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'max_depth': 5, 'learning_rate': 0.055363313812877214, 'subsample': 0.7496782797383683, 'colsample_bytree': 0.6894427576056905, 'reg_alpha': 4.441016481581241, 'reg_lambda': 4.543619387001037, 'min_child_weight': 4}. Best is trial 28 with value: 0.5343939073326731.
# [I 2025-05-20 14:32:12,372] Trial 30 finished with value: 0.57985182645746 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'max_depth': 4, 'learning_rate': 0.03984410552518822, 'subsample': 0.7305099525749702, 'colsample_bytree': 0.6579228184989955, 'reg_alpha': 2.554612505608088, 'reg_lambda': 4.163932743748963, 'min_child_weight': 2}. Best is trial 30 with value: 0.57985182645746.
# [I 2025-05-20 14:32:13,401] Trial 31 finished with value: 0.5371700075922351 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'max_depth': 4, 'learning_rate': 0.03590140787844463, 'subsample': 0.6597352839153371, 'colsample_bytree': 0.6609178420024766, 'reg_alpha': 2.6026887599143285, 'reg_lambda': 4.208513708910212, 'min_child_weight': 1}. Best is trial 30 with value: 0.57985182645746.
# [I 2025-05-20 14:32:14,577] Trial 32 finished with value: 0.5551778838265757 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'max_depth': 4, 'learning_rate': 0.04225748485428746, 'subsample': 0.6520839721352483, 'colsample_bytree': 0.6540406775250145, 'reg_alpha': 2.5343938619566897, 'reg_lambda': 4.2059580012355475, 'min_child_weight': 1}. Best is trial 30 with value: 0.57985182645746.
# [I 2025-05-20 14:32:15,561] Trial 33 finished with value: 0.5375041012865405 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'max_depth': 4, 'learning_rate': 0.04259957316283943, 'subsample': 0.6497353998929086, 'colsample_bytree': 0.6484491454511355, 'reg_alpha': 2.567960614050439, 'reg_lambda': 4.580745690095719, 'min_child_weight': 1}. Best is trial 30 with value: 0.57985182645746.
# [I 2025-05-20 14:32:16,471] Trial 34 finished with value: 0.5534174173047581 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'max_depth': 4, 'learning_rate': 0.04826256121559095, 'subsample': 0.6438624559572015, 'colsample_bytree': 0.6538012714024667, 'reg_alpha': 2.5471742481757476, 'reg_lambda': 4.1978432002999195, 'min_child_weight': 1}. Best is trial 30 with value: 0.57985182645746.
# [I 2025-05-20 14:32:17,364] Trial 35 finished with value: 0.4427475882178721 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': False, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'max_depth': 3, 'learning_rate': 0.0470925906836312, 'subsample': 0.6384774871765172, 'colsample_bytree': 0.60917769397618, 'reg_alpha': 2.304085534560207, 'reg_lambda': 4.7131003959740525, 'min_child_weight': 2}. Best is trial 30 with value: 0.57985182645746.
# [I 2025-05-20 14:32:18,453] Trial 36 finished with value: 0.5693775154548744 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': False, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'max_depth': 4, 'learning_rate': 0.06360492800211115, 'subsample': 0.6476511776309095, 'colsample_bytree': 0.6429947416623656, 'reg_alpha': 2.8342390417690146, 'reg_lambda': 4.186865523841651, 'min_child_weight': 2}. Best is trial 30 with value: 0.57985182645746.
# [I 2025-05-20 14:32:19,308] Trial 37 finished with value: 0.4875403446578946 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': False, 'use_서비스업': True, 'use_음식점': False, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'max_depth': 4, 'learning_rate': 0.06327642720388107, 'subsample': 0.6003410384521173, 'colsample_bytree': 0.6231303800879457, 'reg_alpha': 2.905003296500112, 'reg_lambda': 4.083776825847655, 'min_child_weight': 2}. Best is trial 30 with value: 0.57985182645746.
# [I 2025-05-20 14:32:20,103] Trial 38 finished with value: 0.4211834936884554 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': False, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'max_depth': 3, 'learning_rate': 0.07490462209452217, 'subsample': 0.7300024716161071, 'colsample_bytree': 0.6739114024936637, 'reg_alpha': 1.7169136675932153, 'reg_lambda': 3.0038436485676367, 'min_child_weight': 2}. Best is trial 30 with value: 0.57985182645746.
# [I 2025-05-20 14:32:21,034] Trial 39 finished with value: 0.6125308400547712 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': False, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'max_depth': 4, 'learning_rate': 0.05168390947598354, 'subsample': 0.6981084230532254, 'colsample_bytree': 0.6300833158950763, 'reg_alpha': 2.381547825085256, 'reg_lambda': 3.2644625439672805, 'min_child_weight': 1}. Best is trial 39 with value: 0.6125308400547712.
# [I 2025-05-20 14:32:22,169] Trial 40 finished with value: 0.4578664864960185 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': False, 'use_서비스업': True, 'use_음식점': False, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'max_depth': 3, 'learning_rate': 0.08522745723796424, 'subsample': 0.7022808185582888, 'colsample_bytree': 0.6288187754426512, 'reg_alpha': 1.7669577430349679, 'reg_lambda': 3.1829460500718016, 'min_child_weight': 1}. Best is trial 39 with value: 0.6125308400547712.
# [I 2025-05-20 14:32:23,074] Trial 41 finished with value: 0.6085178058922368 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': False, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'max_depth': 4, 'learning_rate': 0.05253533064310154, 'subsample': 0.680845114408459, 'colsample_bytree': 0.6464921696790908, 'reg_alpha': 2.38839514151646, 'reg_lambda': 4.3085633284948495, 'min_child_weight': 1}. Best is trial 39 with value: 0.6125308400547712.
# [I 2025-05-20 14:32:23,991] Trial 42 finished with value: 0.6084819841700977 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': False, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'max_depth': 4, 'learning_rate': 0.0589633970981749, 'subsample': 0.6908105724754825, 'colsample_bytree': 0.711297652331829, 'reg_alpha': 2.2945739945786263, 'reg_lambda': 3.982898642520695, 'min_child_weight': 2}. Best is trial 39 with value: 0.6125308400547712.
# [I 2025-05-20 14:32:24,881] Trial 43 finished with value: 0.6266675932447636 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': False, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'max_depth': 4, 'learning_rate': 0.06065590530061637, 'subsample': 0.7298546057127474, 'colsample_bytree': 0.7040705513767808, 'reg_alpha': 2.2310999733982517, 'reg_lambda': 3.972303696991541, 'min_child_weight': 2}. Best is trial 43 with value: 0.6266675932447636.
# [I 2025-05-20 14:32:26,156] Trial 44 finished with value: 0.547768748691922 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': False, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'max_depth': 4, 'learning_rate': 0.05238268517490552, 'subsample': 0.7217069700498917, 'colsample_bytree': 0.707825429601721, 'reg_alpha': 2.166695836240216, 'reg_lambda': 3.954351478530076, 'min_child_weight': 3}. Best is trial 43 with value: 0.6266675932447636.
# [I 2025-05-20 14:32:27,090] Trial 45 finished with value: 0.557558104417614 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': False, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'max_depth': 4, 'learning_rate': 0.0693646682944917, 'subsample': 0.686528959558845, 'colsample_bytree': 0.6781248054464337, 'reg_alpha': 1.4549835612480921, 'reg_lambda': 2.624358692959485, 'min_child_weight': 2}. Best is trial 43 with value: 0.6266675932447636.
# [I 2025-05-20 14:32:27,947] Trial 46 finished with value: 0.5276590246709342 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': False, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'max_depth': 4, 'learning_rate': 0.05989483340896143, 'subsample': 0.7132785067243987, 'colsample_bytree': 0.6003817144626202, 'reg_alpha': 2.338601871614038, 'reg_lambda': 3.3454805204993585, 'min_child_weight': 3}. Best is trial 43 with value: 0.6266675932447636.
# [I 2025-05-20 14:32:28,781] Trial 47 finished with value: 0.5819404169443508 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': False, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'max_depth': 3, 'learning_rate': 0.05780955026833155, 'subsample': 0.7407243246989162, 'colsample_bytree': 0.7099379851296512, 'reg_alpha': 1.8738021803724525, 'reg_lambda': 3.4509584908315953, 'min_child_weight': 1}. Best is trial 43 with value: 0.6266675932447636.
# [I 2025-05-20 14:32:29,815] Trial 48 finished with value: 0.5809997269086885 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': False, 'use_서비스업': True, 'use_음식점': False, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'max_depth': 3, 'learning_rate': 0.05222560788872958, 'subsample': 0.668784817207577, 'colsample_bytree': 0.7155982277418945, 'reg_alpha': 1.880222938180589, 'reg_lambda': 2.931239169710695, 'min_child_weight': 1}. Best is trial 43 with value: 0.6266675932447636.
# [I 2025-05-20 14:32:30,722] Trial 49 finished with value: 0.6258303304426116 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': False, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'max_depth': 3, 'learning_rate': 0.06783710402349886, 'subsample': 0.7445126720550559, 'colsample_bytree': 0.6781930810726469, 'reg_alpha': 0.8219499308955218, 'reg_lambda': 3.4715489207534533, 'min_child_weight': 1}. Best is trial 43 with value: 0.6266675932447636.
# 🎯 Best R²: 0.6266675932447636
# ✅ Best params: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': False, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'max_depth': 4, 'learning_rate': 0.06065590530061637, 'subsample': 0.7298546057127474, 'colsample_bytree': 0.7040705513767808, 'reg_alpha': 2.2310999733982517, 'reg_lambda': 3.972303696991541, 'min_child_weight': 2}
# 🔍 선택된 변수들: ['소매업', '의료기관', '서비스업', '음식점', '버스정류장수', '추정 차량등록수']

# %%
def objective_cat(trial):
    # 변수 선택
    selected_features = [col for col in X.columns if trial.suggest_categorical(f"use_{col}", [True, False])]
    if len(selected_features) == 0:
        return -float("inf")
    X_selected = X[selected_features]

    # 하이퍼파라미터
    params = {
        'iterations': trial.suggest_int('iterations', 100, 300),
        'depth': trial.suggest_int('depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1.0, 10.0),
        'bagging_temperature': trial.suggest_float('bagging_temperature', 0.0, 1.0),
        'random_strength': trial.suggest_float('random_strength', 0.0, 1.0)
    }

    model = CatBoostRegressor(**params, verbose=0, random_state=0)
    score = cross_val_score(model, X_selected, y, cv=10, scoring='r2').mean()
    return score

study_cat = optuna.create_study(direction='maximize')
study_cat.optimize(objective_cat, n_trials=50)

print("🎯 [CatBoost] Best R²:", study_cat.best_value)
print("✅ Best params:", study_cat.best_params)
selected_cols_cat = [col for col in X.columns if study_cat.best_params.get(f"use_{col}", False)]
print("🔍 선택된 변수들:", selected_cols_cat)
# Out:
# [I 2025-05-20 14:00:47,913] A new study created in memory with name: no-name-c02ae9a3-b46a-4221-8b9b-0c19dbf56c00
# [I 2025-05-20 14:00:48,938] Trial 0 finished with value: 0.3765526657710846 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': False, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': False, 'use_근린생활시설수': True, 'iterations': 129, 'depth': 3, 'learning_rate': 0.0583522496270607, 'l2_leaf_reg': 2.501035398285321, 'bagging_temperature': 0.05805533431418819, 'random_strength': 0.04541565124488589}. Best is trial 0 with value: 0.3765526657710846.
# [I 2025-05-20 14:00:50,497] Trial 1 finished with value: 0.017259494536950436 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': False, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'iterations': 121, 'depth': 9, 'learning_rate': 0.0908529259348422, 'l2_leaf_reg': 5.118168671097546, 'bagging_temperature': 0.27643337074477314, 'random_strength': 0.7442916635610967}. Best is trial 0 with value: 0.3765526657710846.
# [I 2025-05-20 14:00:52,503] Trial 2 finished with value: 0.023059134277007908 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': False, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'iterations': 170, 'depth': 5, 'learning_rate': 0.03350449219820815, 'l2_leaf_reg': 4.239871246742517, 'bagging_temperature': 0.14988719822818342, 'random_strength': 0.1156134691304267}. Best is trial 0 with value: 0.3765526657710846.
# [I 2025-05-20 14:00:56,035] Trial 3 finished with value: 0.3439839842076569 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': False, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': False, 'use_근린생활시설수': True, 'iterations': 288, 'depth': 4, 'learning_rate': 0.055253901043179676, 'l2_leaf_reg': 6.547963483615757, 'bagging_temperature': 0.25190523493550365, 'random_strength': 0.760082784592532}. Best is trial 0 with value: 0.3765526657710846.
# [I 2025-05-20 14:00:59,660] Trial 4 finished with value: 0.357942903126325 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': False, 'use_교육기관': False, 'use_카드소비': False, 'use_서비스업': True, 'use_음식점': False, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'iterations': 278, 'depth': 4, 'learning_rate': 0.074922613630391, 'l2_leaf_reg': 8.845595657697395, 'bagging_temperature': 0.87454089432045, 'random_strength': 0.584821049029514}. Best is trial 0 with value: 0.3765526657710846.
# [I 2025-05-20 14:01:04,570] Trial 5 finished with value: 0.39476273408519225 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': False, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': False, 'use_근린생활시설수': True, 'iterations': 280, 'depth': 7, 'learning_rate': 0.025957398003252835, 'l2_leaf_reg': 8.00092570047958, 'bagging_temperature': 0.8800085737879013, 'random_strength': 0.5082576109827555}. Best is trial 5 with value: 0.39476273408519225.
# [I 2025-05-20 14:01:07,344] Trial 6 finished with value: 0.48185426574152607 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': False, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': False, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'iterations': 120, 'depth': 4, 'learning_rate': 0.0945779940779811, 'l2_leaf_reg': 6.258439607444647, 'bagging_temperature': 0.8946322700881739, 'random_strength': 0.15374053738845428}. Best is trial 6 with value: 0.48185426574152607.
# [I 2025-05-20 14:01:18,461] Trial 7 finished with value: 0.04062608662485998 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': False, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'iterations': 299, 'depth': 10, 'learning_rate': 0.07187005304655246, 'l2_leaf_reg': 6.283728500002986, 'bagging_temperature': 0.2636208839571942, 'random_strength': 0.40562328105452916}. Best is trial 6 with value: 0.48185426574152607.
# [I 2025-05-20 14:01:21,400] Trial 8 finished with value: 0.5424335648191889 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'iterations': 208, 'depth': 6, 'learning_rate': 0.025455861688702893, 'l2_leaf_reg': 2.4836802469808705, 'bagging_temperature': 0.6243263636496479, 'random_strength': 0.31485641469446934}. Best is trial 8 with value: 0.5424335648191889.
# [I 2025-05-20 14:01:24,628] Trial 9 finished with value: 0.48866988331728 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': False, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': False, 'use_근린생활시설수': True, 'iterations': 233, 'depth': 6, 'learning_rate': 0.06525339778795367, 'l2_leaf_reg': 5.057995367802259, 'bagging_temperature': 0.8850620627198794, 'random_strength': 0.5474683572894345}. Best is trial 8 with value: 0.5424335648191889.
# [I 2025-05-20 14:01:29,594] Trial 10 finished with value: 0.4789746303212186 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': True, 'use_카드소비': False, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'iterations': 212, 'depth': 8, 'learning_rate': 0.013319229375138372, 'l2_leaf_reg': 1.4386861067372443, 'bagging_temperature': 0.5984049402234963, 'random_strength': 0.9985150905092324}. Best is trial 8 with value: 0.5424335648191889.
# [I 2025-05-20 14:01:34,425] Trial 11 finished with value: 0.498656924169208 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': False, 'use_근린생활시설수': True, 'iterations': 227, 'depth': 6, 'learning_rate': 0.03875579719031024, 'l2_leaf_reg': 3.336818818125119, 'bagging_temperature': 0.6436829277828605, 'random_strength': 0.2924629829227544}. Best is trial 8 with value: 0.5424335648191889.
# [I 2025-05-20 14:01:38,953] Trial 12 finished with value: 0.5194870063227504 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': False, 'use_근린생활시설수': True, 'iterations': 242, 'depth': 6, 'learning_rate': 0.03899990406806021, 'l2_leaf_reg': 3.1951938027919438, 'bagging_temperature': 0.6255323154112254, 'random_strength': 0.2742754518936558}. Best is trial 8 with value: 0.5424335648191889.
# [I 2025-05-20 14:01:43,938] Trial 13 finished with value: 0.5240774584674589 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'iterations': 179, 'depth': 7, 'learning_rate': 0.04359258034462319, 'l2_leaf_reg': 1.4733744814045768, 'bagging_temperature': 0.46410529829807784, 'random_strength': 0.26191719654218937}. Best is trial 8 with value: 0.5424335648191889.
# [I 2025-05-20 14:01:50,001] Trial 14 finished with value: 0.49835793667816014 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': True, 'use_카드소비': False, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'iterations': 179, 'depth': 8, 'learning_rate': 0.0100878082054488, 'l2_leaf_reg': 1.05537448144423, 'bagging_temperature': 0.4591849528075813, 'random_strength': 0.290250403990485}. Best is trial 8 with value: 0.5424335648191889.
# [I 2025-05-20 14:01:53,226] Trial 15 finished with value: 0.5089686391825572 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'iterations': 168, 'depth': 7, 'learning_rate': 0.025121364108197538, 'l2_leaf_reg': 2.1476204590512813, 'bagging_temperature': 0.41531635326254324, 'random_strength': 0.400283290908944}. Best is trial 8 with value: 0.5424335648191889.
# [I 2025-05-20 14:01:57,688] Trial 16 finished with value: 0.4805699587993767 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'iterations': 195, 'depth': 8, 'learning_rate': 0.04586636934587946, 'l2_leaf_reg': 3.2485197106832637, 'bagging_temperature': 0.5561915247270727, 'random_strength': 0.1795404158194433}. Best is trial 8 with value: 0.5424335648191889.
# [I 2025-05-20 14:01:59,937] Trial 17 finished with value: 0.5471003808333893 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'iterations': 148, 'depth': 5, 'learning_rate': 0.047925946747337134, 'l2_leaf_reg': 2.2646136123595064, 'bagging_temperature': 0.7297665493980374, 'random_strength': 0.4035481442073934}. Best is trial 17 with value: 0.5471003808333893.
# [I 2025-05-20 14:02:02,854] Trial 18 finished with value: 0.4569004151823495 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': True, 'use_카드소비': False, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'iterations': 148, 'depth': 5, 'learning_rate': 0.023174297333755072, 'l2_leaf_reg': 3.9772136309486354, 'bagging_temperature': 0.7394969224557543, 'random_strength': 0.6427532302934664}. Best is trial 17 with value: 0.5471003808333893.
# [I 2025-05-20 14:02:05,390] Trial 19 finished with value: 0.42488981003307974 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'iterations': 144, 'depth': 5, 'learning_rate': 0.048597039529049375, 'l2_leaf_reg': 9.927871887032776, 'bagging_temperature': 0.7340780725909067, 'random_strength': 0.40455488055496636}. Best is trial 17 with value: 0.5471003808333893.
# [I 2025-05-20 14:02:08,115] Trial 20 finished with value: 0.5548155820992479 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'iterations': 207, 'depth': 3, 'learning_rate': 0.01831308266580453, 'l2_leaf_reg': 2.325005515361374, 'bagging_temperature': 0.7501966960706253, 'random_strength': 0.40919991518881205}. Best is trial 20 with value: 0.5548155820992479.
# [I 2025-05-20 14:02:12,282] Trial 21 finished with value: 0.5571411213265132 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'iterations': 258, 'depth': 3, 'learning_rate': 0.01690011855486588, 'l2_leaf_reg': 2.271265846856483, 'bagging_temperature': 0.7466729235469058, 'random_strength': 0.41148850165893147}. Best is trial 21 with value: 0.5571411213265132.
# [I 2025-05-20 14:02:17,750] Trial 22 finished with value: 0.5356771632617293 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'iterations': 264, 'depth': 3, 'learning_rate': 0.017375097131677834, 'l2_leaf_reg': 2.096554040748787, 'bagging_temperature': 0.9805282706892491, 'random_strength': 0.4384160751940512}. Best is trial 21 with value: 0.5571411213265132.
# [I 2025-05-20 14:02:19,529] Trial 23 finished with value: 0.49078537771695546 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'iterations': 103, 'depth': 3, 'learning_rate': 0.031068599864612967, 'l2_leaf_reg': 4.421373707366385, 'bagging_temperature': 0.756187007946631, 'random_strength': 0.6807188169996228}. Best is trial 21 with value: 0.5571411213265132.
# [I 2025-05-20 14:02:22,682] Trial 24 finished with value: 0.5423838675101941 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'iterations': 252, 'depth': 4, 'learning_rate': 0.017296941127615276, 'l2_leaf_reg': 3.163144190616909, 'bagging_temperature': 0.7750724908952031, 'random_strength': 0.5058239122383945}. Best is trial 21 with value: 0.5571411213265132.
# [I 2025-05-20 14:02:25,007] Trial 25 finished with value: 0.4508603057169407 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'iterations': 196, 'depth': 3, 'learning_rate': 0.08235472247345357, 'l2_leaf_reg': 1.8452505471885934, 'bagging_temperature': 0.6931289106400006, 'random_strength': 0.35583947701851415}. Best is trial 21 with value: 0.5571411213265132.
# [I 2025-05-20 14:02:28,303] Trial 26 finished with value: 0.5324709472688337 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': True, 'use_카드소비': False, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'iterations': 218, 'depth': 4, 'learning_rate': 0.033817290239139305, 'l2_leaf_reg': 3.7273728030963866, 'bagging_temperature': 0.5340907759102418, 'random_strength': 0.47132221205276226}. Best is trial 21 with value: 0.5571411213265132.
# [I 2025-05-20 14:02:32,585] Trial 27 finished with value: 0.5461916362845072 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'iterations': 261, 'depth': 5, 'learning_rate': 0.06220394270321706, 'l2_leaf_reg': 2.6059877036357735, 'bagging_temperature': 0.8076043540270507, 'random_strength': 0.9057686350548771}. Best is trial 21 with value: 0.5571411213265132.
# [I 2025-05-20 14:02:35,980] Trial 28 finished with value: 0.4226326003035831 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'iterations': 151, 'depth': 3, 'learning_rate': 0.018620561965323093, 'l2_leaf_reg': 4.6809419356724025, 'bagging_temperature': 0.9571887896210045, 'random_strength': 0.5995125720290575}. Best is trial 21 with value: 0.5571411213265132.
# [I 2025-05-20 14:02:38,291] Trial 29 finished with value: 0.4947002269637162 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'iterations': 137, 'depth': 3, 'learning_rate': 0.05503391253787569, 'l2_leaf_reg': 2.644379607637404, 'bagging_temperature': 0.8366489294218781, 'random_strength': 0.21075899191008374}. Best is trial 21 with value: 0.5571411213265132.
# [I 2025-05-20 14:02:40,031] Trial 30 finished with value: 0.5534155006930982 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'iterations': 161, 'depth': 4, 'learning_rate': 0.04991065380224181, 'l2_leaf_reg': 1.1908683932466482, 'bagging_temperature': 0.006759610066830568, 'random_strength': 0.010714453680519098}. Best is trial 21 with value: 0.5571411213265132.
# [I 2025-05-20 14:02:41,956] Trial 31 finished with value: 0.5309156430150971 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'iterations': 158, 'depth': 4, 'learning_rate': 0.05013020695676916, 'l2_leaf_reg': 1.0085630911205286, 'bagging_temperature': 0.0033117896372088637, 'random_strength': 0.019543824223245736}. Best is trial 21 with value: 0.5571411213265132.
# [I 2025-05-20 14:02:43,391] Trial 32 finished with value: 0.5092322791199378 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'iterations': 129, 'depth': 3, 'learning_rate': 0.039966604823661975, 'l2_leaf_reg': 1.7457012063165336, 'bagging_temperature': 0.37716736248787985, 'random_strength': 0.07662662805821752}. Best is trial 21 with value: 0.5571411213265132.
# [I 2025-05-20 14:02:46,198] Trial 33 finished with value: 0.5464954764664623 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'iterations': 183, 'depth': 5, 'learning_rate': 0.030789717873790326, 'l2_leaf_reg': 2.721240291959572, 'bagging_temperature': 0.13070760719815272, 'random_strength': 0.34435267655929375}. Best is trial 21 with value: 0.5571411213265132.
# [I 2025-05-20 14:02:48,433] Trial 34 finished with value: 0.5949538208054592 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'iterations': 160, 'depth': 4, 'learning_rate': 0.060334051517762693, 'l2_leaf_reg': 2.157397621389604, 'bagging_temperature': 0.6837010921833764, 'random_strength': 0.2247769333799387}. Best is trial 34 with value: 0.5949538208054592.
# [I 2025-05-20 14:02:50,100] Trial 35 finished with value: 0.14704137719685123 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': False, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'iterations': 160, 'depth': 4, 'learning_rate': 0.0688726981829733, 'l2_leaf_reg': 5.6701603954376765, 'bagging_temperature': 0.678478658917933, 'random_strength': 0.10605146231946372}. Best is trial 34 with value: 0.5949538208054592.
# [I 2025-05-20 14:02:51,991] Trial 36 finished with value: 0.4695007320356848 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'iterations': 187, 'depth': 3, 'learning_rate': 0.08308249982150626, 'l2_leaf_reg': 1.474452910349413, 'bagging_temperature': 0.33076041841554193, 'random_strength': 0.21800888707276728}. Best is trial 34 with value: 0.5949538208054592.
# [I 2025-05-20 14:02:53,578] Trial 37 finished with value: 0.0892366045160394 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': True, 'use_카드소비': False, 'use_서비스업': False, 'use_음식점': False, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'iterations': 169, 'depth': 4, 'learning_rate': 0.05959466611221062, 'l2_leaf_reg': 3.6274067885835817, 'bagging_temperature': 0.1812764529694838, 'random_strength': 0.06115330010584752}. Best is trial 34 with value: 0.5949538208054592.
# [I 2025-05-20 14:02:55,094] Trial 38 finished with value: 0.5394663292256632 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'iterations': 114, 'depth': 4, 'learning_rate': 0.053821840622359084, 'l2_leaf_reg': 1.0454029114169203, 'bagging_temperature': 0.5683942308518097, 'random_strength': 0.1637509355587815}. Best is trial 34 with value: 0.5949538208054592.
# [I 2025-05-20 14:02:56,701] Trial 39 finished with value: 0.574976362807548 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'iterations': 205, 'depth': 3, 'learning_rate': 0.08362865393655482, 'l2_leaf_reg': 8.196450627133867, 'bagging_temperature': 0.8104624871346793, 'random_strength': 0.003546333348393396}. Best is trial 34 with value: 0.5949538208054592.
# [I 2025-05-20 14:02:58,816] Trial 40 finished with value: 0.39519959349007144 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': False, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': False, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'iterations': 225, 'depth': 3, 'learning_rate': 0.0996687941871458, 'l2_leaf_reg': 7.155286062819258, 'bagging_temperature': 0.8336169986876174, 'random_strength': 0.7827751775051488}. Best is trial 34 with value: 0.5949538208054592.
# [I 2025-05-20 14:03:00,829] Trial 41 finished with value: 0.5470846243158556 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'iterations': 245, 'depth': 3, 'learning_rate': 0.07992922600795406, 'l2_leaf_reg': 8.618317755759437, 'bagging_temperature': 0.688456537378236, 'random_strength': 0.012367281683065832}. Best is trial 34 with value: 0.5949538208054592.
# [I 2025-05-20 14:03:03,304] Trial 42 finished with value: 0.5732981864561594 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'iterations': 213, 'depth': 4, 'learning_rate': 0.07656834509862648, 'l2_leaf_reg': 7.0424582408546, 'bagging_temperature': 0.9201717616016873, 'random_strength': 0.11556486101535657}. Best is trial 34 with value: 0.5949538208054592.
# [I 2025-05-20 14:03:05,505] Trial 43 finished with value: 0.5725552424741885 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'iterations': 210, 'depth': 3, 'learning_rate': 0.08923888190798338, 'l2_leaf_reg': 7.419458737024277, 'bagging_temperature': 0.9197951084107383, 'random_strength': 0.11030964391077004}. Best is trial 34 with value: 0.5949538208054592.
# [I 2025-05-20 14:03:07,859] Trial 44 finished with value: 0.5248759200381914 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'iterations': 232, 'depth': 4, 'learning_rate': 0.08916174054657791, 'l2_leaf_reg': 7.6571297346314795, 'bagging_temperature': 0.9299004085776112, 'random_strength': 0.12621283361955143}. Best is trial 34 with value: 0.5949538208054592.
# [I 2025-05-20 14:03:09,784] Trial 45 finished with value: 0.5485689067672959 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'iterations': 201, 'depth': 3, 'learning_rate': 0.08913636816499164, 'l2_leaf_reg': 6.964636290079563, 'bagging_temperature': 0.9243548734592894, 'random_strength': 0.08406062172867944}. Best is trial 34 with value: 0.5949538208054592.
# [I 2025-05-20 14:03:12,168] Trial 46 finished with value: -0.3497126164936824 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': True, 'use_카드소비': False, 'use_서비스업': False, 'use_음식점': False, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'iterations': 211, 'depth': 4, 'learning_rate': 0.07752323199508267, 'l2_leaf_reg': 8.25451490754657, 'bagging_temperature': 0.9977600140406476, 'random_strength': 0.1384215170644743}. Best is trial 34 with value: 0.5949538208054592.
# [I 2025-05-20 14:03:19,017] Trial 47 finished with value: 0.3572917201061529 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'iterations': 285, 'depth': 9, 'learning_rate': 0.06978469567596679, 'l2_leaf_reg': 9.323735448465804, 'bagging_temperature': 0.8566329551428308, 'random_strength': 0.23960257510910313}. Best is trial 34 with value: 0.5949538208054592.
# [I 2025-05-20 14:03:23,217] Trial 48 finished with value: 0.5096955133343741 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'iterations': 271, 'depth': 5, 'learning_rate': 0.09354638714600937, 'l2_leaf_reg': 5.933804590402961, 'bagging_temperature': 0.79872809785532, 'random_strength': 0.2002273447148402}. Best is trial 34 with value: 0.5949538208054592.
# [I 2025-05-20 14:03:26,464] Trial 49 finished with value: 0.6001463913416216 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': False, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'iterations': 222, 'depth': 3, 'learning_rate': 0.08468615081647429, 'l2_leaf_reg': 7.4645110045971395, 'bagging_temperature': 0.9086172715884305, 'random_strength': 0.0672721307121702}. Best is trial 49 with value: 0.6001463913416216.
# 🎯 [CatBoost] Best R²: 0.6001463913416216
# ✅ Best params: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': False, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'iterations': 222, 'depth': 3, 'learning_rate': 0.08468615081647429, 'l2_leaf_reg': 7.4645110045971395, 'bagging_temperature': 0.9086172715884305, 'random_strength': 0.0672721307121702}
# 🔍 선택된 변수들: ['소매업', '카드소비', '음식점', '버스정류장수']

# %%
def objective_rf(trial):
    # 변수 선택
    selected_features = [col for col in X.columns if trial.suggest_categorical(f"use_{col}", [True, False])]
    if len(selected_features) == 0:
        return -float("inf")
    X_selected = X[selected_features]

    # 하이퍼파라미터
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 300),
        'max_depth': trial.suggest_int('max_depth', 3, 15),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 10),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
        'max_features': trial.suggest_categorical('max_features', [None, 'sqrt', 'log2']),
        'bootstrap': trial.suggest_categorical('bootstrap', [True, False])
    }

    model = RandomForestRegressor(**params, random_state=0)
    score = cross_val_score(model, X_selected, y, cv=10, scoring='r2').mean()
    return score

study_rf = optuna.create_study(direction='maximize')
study_rf.optimize(objective_rf, n_trials=50)

print("🎯 [RandomForest] Best R²:", study_rf.best_value)
print("✅ Best params:", study_rf.best_params)
selected_cols_rf = [col for col in X.columns if study_rf.best_params.get(f"use_{col}", False)]
print("🔍 선택된 변수들:", selected_cols_rf)
# Out:
# [I 2025-05-20 14:05:06,249] A new study created in memory with name: no-name-f38ec5b6-73d3-4693-8198-fa5b1e15feb1
# [I 2025-05-20 14:05:07,031] Trial 0 finished with value: 0.511543664908998 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 182, 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 6, 'max_features': 'log2', 'bootstrap': False}. Best is trial 0 with value: 0.511543664908998.
# [I 2025-05-20 14:05:08,733] Trial 1 finished with value: 0.43692016478766416 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': False, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 286, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 0 with value: 0.511543664908998.
# [I 2025-05-20 14:05:09,695] Trial 2 finished with value: 0.5075371337935534 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'n_estimators': 157, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 0 with value: 0.511543664908998.
# [I 2025-05-20 14:05:10,532] Trial 3 finished with value: 0.36220180783817935 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': False, 'use_교육기관': False, 'use_카드소비': False, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'n_estimators': 131, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True}. Best is trial 0 with value: 0.511543664908998.
# [I 2025-05-20 14:05:11,531] Trial 4 finished with value: 0.2791610067439151 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 173, 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': False}. Best is trial 0 with value: 0.511543664908998.
# [I 2025-05-20 14:05:13,842] Trial 5 finished with value: 0.45296854580662876 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': False, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': False, 'use_근린생활시설수': True, 'n_estimators': 285, 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 0 with value: 0.511543664908998.
# [I 2025-05-20 14:05:14,961] Trial 6 finished with value: 0.4526835704455226 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': True, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': False, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'n_estimators': 223, 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 0 with value: 0.511543664908998.
# [I 2025-05-20 14:05:15,907] Trial 7 finished with value: 0.4060823210412453 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'n_estimators': 125, 'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': False}. Best is trial 0 with value: 0.511543664908998.
# [I 2025-05-20 14:05:18,007] Trial 8 finished with value: 0.4071137044496706 and parameters: {'use_생활 인구': False, 'use_소매업': True, 'use_의료기관': False, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': False, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'n_estimators': 244, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 0 with value: 0.511543664908998.
# [I 2025-05-20 14:05:19,355] Trial 9 finished with value: 0.39578014250670507 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': False, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'n_estimators': 240, 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 0 with value: 0.511543664908998.
# [I 2025-05-20 14:05:20,379] Trial 10 finished with value: 0.5097712743423081 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': True, 'use_카드소비': False, 'use_서비스업': False, 'use_음식점': False, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 185, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_features': 'log2', 'bootstrap': False}. Best is trial 0 with value: 0.511543664908998.
# [I 2025-05-20 14:05:21,424] Trial 11 finished with value: 0.5102292639763057 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': True, 'use_카드소비': False, 'use_서비스업': False, 'use_음식점': False, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 190, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_features': 'log2', 'bootstrap': False}. Best is trial 0 with value: 0.511543664908998.
# [I 2025-05-20 14:05:22,678] Trial 12 finished with value: 0.5065440686283045 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': True, 'use_카드소비': False, 'use_서비스업': False, 'use_음식점': False, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 212, 'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 8, 'max_features': 'log2', 'bootstrap': False}. Best is trial 0 with value: 0.511543664908998.
# [I 2025-05-20 14:05:23,541] Trial 13 finished with value: 0.503321463984106 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': True, 'use_카드소비': False, 'use_서비스업': False, 'use_음식점': False, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 153, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 'log2', 'bootstrap': False}. Best is trial 0 with value: 0.511543664908998.
# [I 2025-05-20 14:05:24,129] Trial 14 finished with value: 0.429287218524423 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 102, 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': 'log2', 'bootstrap': False}. Best is trial 0 with value: 0.511543664908998.
# [I 2025-05-20 14:05:25,247] Trial 15 finished with value: 0.5122124797084517 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': True, 'use_카드소비': False, 'use_서비스업': False, 'use_음식점': False, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 200, 'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 7, 'max_features': 'log2', 'bootstrap': False}. Best is trial 15 with value: 0.5122124797084517.
# [I 2025-05-20 14:05:26,917] Trial 16 finished with value: 0.5512712635910444 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 255, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 7, 'max_features': 'log2', 'bootstrap': False}. Best is trial 16 with value: 0.5512712635910444.
# [I 2025-05-20 14:05:28,429] Trial 17 finished with value: 0.5151594976624677 and parameters: {'use_생활 인구': True, 'use_소매업': True, 'use_의료기관': True, 'use_교육기관': True, 'use_카드소비': False, 'use_서비스업': False, 'use_음식점': False, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 261, 'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': 'log2', 'bootstrap': False}. Best is trial 16 with value: 0.5512712635910444.
# [I 2025-05-20 14:05:29,951] Trial 18 finished with value: 0.5541685338707514 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 262, 'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 9, 'max_features': 'log2', 'bootstrap': False}. Best is trial 18 with value: 0.5541685338707514.
# [I 2025-05-20 14:05:31,363] Trial 19 finished with value: 0.5541885754800203 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 263, 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': 'log2', 'bootstrap': False}. Best is trial 19 with value: 0.5541885754800203.
# [I 2025-05-20 14:05:32,986] Trial 20 finished with value: 0.5588783607411416 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 296, 'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': 'log2', 'bootstrap': False}. Best is trial 20 with value: 0.5588783607411416.
# [I 2025-05-20 14:05:34,522] Trial 21 finished with value: 0.5586102675368637 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 299, 'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': 'log2', 'bootstrap': False}. Best is trial 20 with value: 0.5588783607411416.
# [I 2025-05-20 14:05:36,047] Trial 22 finished with value: 0.5579074677058692 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 297, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': 'log2', 'bootstrap': False}. Best is trial 20 with value: 0.5588783607411416.
# [I 2025-05-20 14:05:37,625] Trial 23 finished with value: 0.5586102675368637 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 299, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': 'log2', 'bootstrap': False}. Best is trial 20 with value: 0.5588783607411416.
# [I 2025-05-20 14:05:39,111] Trial 24 finished with value: 0.5226113519571025 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 300, 'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 10, 'max_features': 'log2', 'bootstrap': False}. Best is trial 20 with value: 0.5588783607411416.
# [I 2025-05-20 14:05:40,606] Trial 25 finished with value: 0.5566828022158361 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 279, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': 'log2', 'bootstrap': False}. Best is trial 20 with value: 0.5588783607411416.
# [I 2025-05-20 14:05:42,676] Trial 26 finished with value: 0.49543471627598346 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 275, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 10, 'max_features': 'log2', 'bootstrap': True}. Best is trial 20 with value: 0.5588783607411416.
# [I 2025-05-20 14:05:43,912] Trial 27 finished with value: 0.5533635286164218 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 228, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 9, 'max_features': 'log2', 'bootstrap': False}. Best is trial 20 with value: 0.5588783607411416.
# [I 2025-05-20 14:05:45,623] Trial 28 finished with value: 0.03186685277094027 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 300, 'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': False}. Best is trial 20 with value: 0.5588783607411416.
# [I 2025-05-20 14:05:47,697] Trial 29 finished with value: 0.48542743769886176 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 276, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': 'log2', 'bootstrap': False}. Best is trial 20 with value: 0.5588783607411416.
# [I 2025-05-20 14:05:49,104] Trial 30 finished with value: 0.4318476257243592 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 246, 'max_depth': 8, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': False}. Best is trial 20 with value: 0.5588783607411416.
# [I 2025-05-20 14:05:50,715] Trial 31 finished with value: 0.5601422787066419 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 294, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': 'log2', 'bootstrap': False}. Best is trial 31 with value: 0.5601422787066419.
# [I 2025-05-20 14:05:52,210] Trial 32 finished with value: 0.56261096844478 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 288, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 8, 'max_features': 'log2', 'bootstrap': False}. Best is trial 32 with value: 0.56261096844478.
# [I 2025-05-20 14:05:53,662] Trial 33 finished with value: 0.5599497409229547 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 286, 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_features': 'log2', 'bootstrap': False}. Best is trial 32 with value: 0.56261096844478.
# [I 2025-05-20 14:05:55,986] Trial 34 finished with value: 0.5119172376143855 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 271, 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 32 with value: 0.56261096844478.
# [I 2025-05-20 14:05:57,521] Trial 35 finished with value: 0.36708330338864664 and parameters: {'use_생활 인구': True, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': False, 'use_버스정류장수': True, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'n_estimators': 286, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': 'log2', 'bootstrap': False}. Best is trial 32 with value: 0.56261096844478.
# [I 2025-05-20 14:05:59,902] Trial 36 finished with value: 0.5682801876970345 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 288, 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 8, 'max_features': 'log2', 'bootstrap': True}. Best is trial 36 with value: 0.5682801876970345.
# [I 2025-05-20 14:06:02,312] Trial 37 finished with value: 0.43178343794358043 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 285, 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': True}. Best is trial 36 with value: 0.5682801876970345.
# [I 2025-05-20 14:06:04,631] Trial 38 finished with value: 0.5403259125552068 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'n_estimators': 286, 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 36 with value: 0.5682801876970345.
# [I 2025-05-20 14:06:06,763] Trial 39 finished with value: 0.49170110769097863 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 252, 'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': True}. Best is trial 36 with value: 0.5682801876970345.
# [I 2025-05-20 14:06:09,023] Trial 40 finished with value: 0.3752063856697947 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': False, 'use_근린생활시설수': False, 'n_estimators': 266, 'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': True}. Best is trial 36 with value: 0.5682801876970345.
# [I 2025-05-20 14:06:11,433] Trial 41 finished with value: 0.5685606830095271 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 287, 'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 8, 'max_features': 'log2', 'bootstrap': True}. Best is trial 41 with value: 0.5685606830095271.
# [I 2025-05-20 14:06:13,793] Trial 42 finished with value: 0.568951259166692 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 286, 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_features': 'log2', 'bootstrap': True}. Best is trial 42 with value: 0.568951259166692.
# [I 2025-05-20 14:06:16,346] Trial 43 finished with value: 0.5673945642227519 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 273, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': 'log2', 'bootstrap': True}. Best is trial 42 with value: 0.568951259166692.
# [I 2025-05-20 14:06:18,699] Trial 44 finished with value: 0.5680216055065417 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 270, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 42 with value: 0.568951259166692.
# [I 2025-05-20 14:06:20,860] Trial 45 finished with value: 0.5794976883444318 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 229, 'max_depth': 11, 'min_samples_split': 6, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 45 with value: 0.5794976883444318.
# [I 2025-05-20 14:06:23,162] Trial 46 finished with value: 0.5194606971005633 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': False, 'use_카드소비': True, 'use_서비스업': True, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': True, 'use_추정 차량등록수': False, 'use_근린생활시설수': True, 'n_estimators': 232, 'max_depth': 11, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 45 with value: 0.5794976883444318.
# [I 2025-05-20 14:06:25,242] Trial 47 finished with value: 0.42783124545805 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': False, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': False, 'n_estimators': 218, 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 45 with value: 0.5794976883444318.
# [I 2025-05-20 14:06:27,508] Trial 48 finished with value: 0.5790879723709055 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 237, 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 45 with value: 0.5794976883444318.
# [I 2025-05-20 14:06:29,650] Trial 49 finished with value: 0.5060953317138919 and parameters: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': False, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 199, 'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 45 with value: 0.5794976883444318.
# 🎯 [RandomForest] Best R²: 0.5794976883444318
# ✅ Best params: {'use_생활 인구': False, 'use_소매업': False, 'use_의료기관': False, 'use_교육기관': True, 'use_카드소비': True, 'use_서비스업': False, 'use_음식점': True, 'use_지역면적(km^2)': True, 'use_버스정류장수': False, 'use_추정 차량등록수': True, 'use_근린생활시설수': True, 'n_estimators': 229, 'max_depth': 11, 'min_samples_split': 6, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': True}
# 🔍 선택된 변수들: ['교육기관', '카드소비', '음식점', '지역면적(km^2)', '추정 차량등록수', '근린생활시설수']

# %%
def evaluate_model(study, model_class, model_name):
    # 선택된 feature
    selected_cols = [col for col in X.columns if study.best_params.get(f"use_{col}", False)]
    X_selected = X[selected_cols]
    
    n, p = X_selected.shape

    # 모델 파라미터만 추출 (use_로 시작하는 건 제외)
    best_params = {k: v for k, v in study.best_params.items() if not k.startswith('use_')}

    # 모델 인스턴스화
    if model_name == 'CatBoost':
        model = model_class(**best_params, verbose=0, random_state=0)
    else:
        model = model_class(**best_params, random_state=0)

    # R²
    r2 = cross_val_score(model, X_selected, y, cv=10, scoring='r2').mean()

    # Adjusted R²
    adj_r2 = 1 - (1 - r2) * (n - 1) / (n - p - 1)

    # RMSE
    neg_mse = cross_val_score(model, X_selected, y, cv=10, scoring='neg_mean_squared_error')
    rmse = np.mean(np.sqrt(-neg_mse))

    # MAE
    neg_mae = cross_val_score(model, X_selected, y, cv=10, scoring='neg_mean_absolute_error')
    mae = np.mean(-neg_mae)

    # 결과 출력
    print(f"\n📌 [{model_name}] 최적 파라미터:")
    print(best_params)
    print("🔍 선택된 변수들:", selected_cols)
    print("📊 교차검증 기반 성능 지표:")
    print(f"R²            : {r2:.5f}")
    print(f"Adjusted R²   : {adj_r2:.5f}")
    print(f"RMSE          : {rmse:.5f}")
    print(f"MAE           : {mae:.5f}")

# 세 모델 각각 평가
evaluate_model(study_xgb, XGBRegressor, "XGBoost")
evaluate_model(study_cat, CatBoostRegressor, "CatBoost")
evaluate_model(study_rf, RandomForestRegressor, "Random Forest")
# Out:
# 📌 [XGBoost] 최적 파라미터:
# {'max_depth': 4, 'learning_rate': 0.06065590530061637, 'subsample': 0.7298546057127474, 'colsample_bytree': 0.7040705513767808, 'reg_alpha': 2.2310999733982517, 'reg_lambda': 3.972303696991541, 'min_child_weight': 2}
# 🔍 선택된 변수들: ['소매업', '의료기관', '서비스업', '음식점', '버스정류장수', '추정 차량등록수']
# 📊 교차검증 기반 성능 지표:
# R²            : 0.62667
# Adjusted R²   : 0.56613
# RMSE          : 1787.03743
# MAE           : 1274.97578
#
# 📌 [CatBoost] 최적 파라미터:
# {'iterations': 222, 'depth': 3, 'learning_rate': 0.08468615081647429, 'l2_leaf_reg': 7.4645110045971395, 'bagging_temperature': 0.9086172715884305, 'random_strength': 0.0672721307121702}
# 🔍 선택된 변수들: ['소매업', '카드소비', '음식점', '버스정류장수']
# 📊 교차검증 기반 성능 지표:
# R²            : 0.60015
# Adjusted R²   : 0.55914
# RMSE          : 1822.55570
# MAE           : 1301.46925
#
# 📌 [Random Forest] 최적 파라미터:
# {'n_estimators': 229, 'max_depth': 11, 'min_samples_split': 6, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': True}
# 🔍 선택된 변수들: ['교육기관', '카드소비', '음식점', '지역면적(km^2)', '추정 차량등록수', '근린생활시설수']
# 📊 교차검증 기반 성능 지표:
# R²            : 0.57950
# Adjusted R²   : 0.51131
# RMSE          : 1806.44586
# MAE           : 1305.97460

# %%
# 1. 최적 변수 선택
selected_cols = [col for col in X.columns if study_xgb.best_params.get(f"use_{col}", False)]
X_selected = X[selected_cols]

# 2. 최적 파라미터만 추출
best_params = {k: v for k, v in study_xgb.best_params.items() if not k.startswith('use_')}

# 3. 최적 모델 학습
best_model = XGBRegressor(**best_params, random_state=0)
best_model.fit(X_selected, y)  # 전체 데이터로 학습

# 4. 예측 수행
df['예측_적정주차면수'] = best_model.predict(X_selected)

# 5. 필요 주차면수 계산
df['필요주차면수'] = df['예측_적정주차면수'] - df['주차면수 합']

# 6. 우선순위지수 계산
df['우선순위지수'] = df['필요주차면수'] * (df['유입인구'] / df['유입인구'].sum())
df['우선순위지수'] = (df['우선순위지수'] / df['우선순위지수'].max()).round(3)

# 7. 우선순위 상위 10개 출력
df_sorted = df.sort_values(by='우선순위지수', ascending=False)
print("\n🏆 우선 설치 대상 상위 10개 행정동:")
print(df_sorted[['행정동', '필요주차면수', '우선순위지수']].head(10))
# Out:
# 🏆 우선 설치 대상 상위 10개 행정동:
#      행정동       필요주차면수  우선순위지수
# 25   인계동  5839.697266   1.000
# 37  광교1동  3794.630859   0.674
# 27   매산동  3974.218750   0.392
# 41  영통3동  3311.927734   0.389
# 16  권선1동  3312.462891   0.374
# 13    평동  2771.009766   0.310
# 36   원천동  2055.916016   0.301
# 31   행궁동  4634.782227   0.289
# 17   곡선동  3577.633789   0.273
# 34  매탄3동  2094.545410   0.255

# %%
df_sorted[['행정동', '적정 주차면수', '예측_적정주차면수', '주차면수 합', '필요주차면수', '유입인구', '우선순위지수']].head(10)
# Out:
#      행정동     적정 주차면수     예측_적정주차면수  주차면수 합       필요주차면수   유입인구  우선순위지수
# 25   인계동  22319.0312  13662.697266    7823  5839.697266  57072   1.000
# 37  광교1동   8112.4000   8947.630859    5153  3794.630859  59223   0.674
# 27   매산동   4748.2300   5532.218750    1558  3974.218750  32910   0.392
# 41  영통3동   8548.0600   9221.927734    5910  3311.927734  39170   0.389
# 16  권선1동   7467.5400   7399.462891    4087  3312.462891  37583   0.374
# 13    평동   8724.3500   8823.009766    6052  2771.009766  37331   0.310
# 36   원천동   6887.6600   7023.916016    4968  2055.916016  48780   0.301
# 31   행궁동   7313.4800   7715.782227    3081  4634.782227  20771   0.289
# 17   곡선동  11512.4500  10567.633789    6990  3577.633789  25418   0.273
# 34  매탄3동   6127.9000   6078.545410    3984  2094.545410  40571   0.255
